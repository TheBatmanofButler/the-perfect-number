# %% [markdown]
# # advanced Exploratory Data Analysis
# ## Corporate Tax Cut Project

# %%
import pandas as pd
import missingno as mn
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['figure.figsize'] = [20, 10]

# %% [markdown]
# ### Transferred "CEO Pay and Employment Data at Tax-Dodging Corporations" table from Appendix 1 of report into `ips_appendix1.csv`

# %%
ips_appendix1_A = pd.read_csv('ips_appendix1.csv')
ips_appendix1_A.columns = ['Company Name', 'Profit ($mil 2008-2015)', 'Fed Tax Paid ($mil 2008-2015)', 'Effective Tax Rate (% 2008-2015)','Employee count (# end of 2016)', 'Difference in employee count (# 2008-2016)','Adjusted percent change (% 2008-2016)', 'CEO compensation ($ 2016)', 'CEO compensation % change (2008-2016)']
ips_appendix1_A.index = ips_appendix1_A['Company Name']
ips_appendix1_A.drop(ips_appendix1_A.columns[0], axis = 1, inplace=True)
ips_appendix1_A.head()
# Out:
#                      Profit ($mil 2008-2015)  Fed Tax Paid ($mil 2008-2015)  \
# Company Name
# AT&T                                  141624                          11500
# Verizon                                81518                           7401
# ExxonMobil                             60482                           8227
# United Technologies                    24421                           2546
# JPMorgan Chase                        114770                          17956
#
#                      Effective Tax Rate (% 2008-2015)  \
# Company Name
# AT&T                                              8.1
# Verizon                                           9.1
# ExxonMobil                                       13.6
# United Technologies                              10.4
# JPMorgan Chase                                   15.6
#
#                      Employee count (# end of 2016)  \
# Company Name
# AT&T                                         268000
# Verizon                                      160900
# ExxonMobil                                    72700
# United Technologies                          201600
# JPMorgan Chase                               243000
#
#                      Difference in employee count (# 2008-2016)  \
# Company Name
# AT&T                                                     -79450
# Verizon                                                  -78450
# ExxonMobil                                               -37735
# United Technologies                                      -37000
# JPMorgan Chase                                           -26961
#
#                      Adjusted percent change (% 2008-2016)  \
# Company Name
# AT&T                                                   -23
# Verizon                                                -33
# ExxonMobil                                             -34
# United Technologies                                    -16
# JPMorgan Chase                                         -10
#
#                      CEO compensation ($ 2016)  \
# Company Name
# AT&T                                  28433716
# Verizon                               17674579
# ExxonMobil                            27393567
# United Technologies                   15831335
# JPMorgan Chase                        27236892
#
#                      CEO compensation % change (2008-2016)
# Company Name
# AT&T                                                   146
# Verizon                                                 -5
# ExxonMobil                                              22
# United Technologies                                    -12
# JPMorgan Chase                                          39

# %% [markdown]
# ### Transferred "Effective Federal Corporate Income Tax Rates on 258 Major Corporations, 2008–2015 (alphabetical)" table from Report A into `itep_tax_rates.csv`

# %%
itep_tax_rates_B = pd.read_csv('itep_tax_rates.csv', na_values=['NaN'])
itep_tax_rates_B.columns= ['Company Name', 'Profit ($mil Eight Year Total)', 'Tax ($mil Eight Year Total)',
       'Rate (% Eight Year Total)', 'Profit ($mil 2015)', 'Tax ($mil 2015)', 'Rate (% 2015)',
       'Profit ($mil 2014)', 'Tax ($mil 2014)', 'Rate (% 2014)', 'Profit ($mil 2013)',
       'Tax ($mil 2013)', 'Rate (% 2013)', 'Profit ($mil 2008-12)', 'Tax ($mil 2008-12)',
       'Rate (% 2008-12)']
itep_tax_rates_B.index = itep_tax_rates_B['Company Name']
itep_tax_rates_B.drop(itep_tax_rates_B.columns[0], axis = 1, inplace=True)
itep_tax_rates_B.head()
# Out:
#                     Profit ($mil Eight Year Total)  \
# Company Name
# 3M                                         23794.4
# ABM Industries                               696.0
# Advance Auto Parts                          4471.8
# Aetna                                      22564.1
# AGL Resources                               3680.2
#
#                     Tax ($mil Eight Year Total)  Rate (% Eight Year Total)  \
# Company Name
# 3M                                       5860.6                       24.6
# ABM Industries                             84.2                       12.1
# Advance Auto Parts                       1288.8                       28.8
# Aetna                                    7290.8                       32.3
# AGL Resources                             279.2                        7.6
#
#                     Profit ($mil 2015)  Tax ($mil 2015)  Rate (% 2015)  \
# Company Name
# 3M                              4349.7           1210.6           27.8
# ABM Industries                    57.2              1.8            3.1
# Advance Auto Parts               670.6            232.0           34.6
# Aetna                           4133.0           1753.1           42.4
# AGL Resources                    556.0            -11.0           -2.0
#
#                     Profit ($mil 2014)  Tax ($mil 2014)  Rate (% 2014)  \
# Company Name
# 3M                              3735.9            964.9           25.8
# ABM Industries                   110.1             32.0           29.1
# Advance Auto Parts               703.9            196.1           27.9
# Aetna                           3423.0           1198.8           35.0
# AGL Resources                    874.0            113.0           12.9
#
#                     Profit ($mil 2013)  Tax ($mil 2013)  Rate (% 2013)  \
# Company Name
# 3M                              3118.9            871.9           28.0
# ABM Industries                    97.7             15.3           15.7
# Advance Auto Parts               568.7            189.3           33.3
# Aetna                           2899.2            832.9           28.7
# AGL Resources                    469.0            166.0           35.4
#
#                     Profit ($mil 2008-12)  Tax ($mil 2008-12)  \
# Company Name
# 3M                                12589.9              2813.1
# ABM Industries                      431.0                35.0
# Advance Auto Parts                 2528.7               671.4
# Aetna                             12108.8              3505.9
# AGL Resources                      1781.2                11.2
#
#                     Rate (% 2008-12)
# Company Name
# 3M                              22.3
# ABM Industries                   8.1
# Advance Auto Parts              26.6
# Aetna                           29.0
# AGL Resources                    0.6

# %% [markdown]
# ### Transferred "Effective Federal Corporate Income Tax Rates on 258 Major Corporations, 2008–2015 (alphabetical)" table from Report A into `itep_foreign.csv`

# %%
itep_foreign_B = pd.read_csv('itep_foreign.csv')
itep_foreign_B.columns = ['Company Name', 'US profit', 'US tax', 'US rate', 'Foreign profit', 'Foreign tax',
                          'Foreign rate', 'US rate - Foreign rate']
itep_foreign_B.index = itep_foreign_B['Company Name']
itep_foreign_B.drop(itep_foreign_B.columns[0], axis = 1, inplace=True)
itep_foreign_B.head()
# Out:
#                                  US profit  US tax  US rate  Foreign profit  \
# Company Name
# Wal-Mart Stores                     145059   48796     33.6           42692
# General Electric                     40375   -1051     -2.6           85495
# J.P. Morgan Chase & Co.             121544   24731     20.3           59592
# McKesson                             11973    2766     23.1            4811
# International Business Machines      66753    6874     10.3           86183
#
#                                  Foreign tax  Foreign rate  \
# Company Name
# Wal-Mart Stores                        11562          27.1
# General Electric                       27726          32.4
# J.P. Morgan Chase & Co.                12935          21.7
# McKesson                                 576          12.0
# International Business Machines        21639          25.1
#
#                                  US rate - Foreign rate
# Company Name
# Wal-Mart Stores                                     6.6
# General Electric                                  -35.0
# J.P. Morgan Chase & Co.                            -1.4
# McKesson                                           11.1
# International Business Machines                   -14.8

# %%
itep_corp_indust_B = pd.read_csv('itep_corp_indust.csv')
itep_corp_indust_B.columns = ['Company Name', 'Industry']
itep_corp_indust_B.index = itep_corp_indust_B['Company Name']
itep_corp_indust_B.drop(itep_corp_indust_B.columns[0], axis = 1, inplace=True)
itep_corp_indust_B.head()
# Out:
#                                 Industry
# Company Name
# Boeing               Aerospace & defense
# United Technologies  Aerospace & defense
# Rockwell Collins     Aerospace & defense
# L-3 Communications   Aerospace & defense
# Raytheon             Aerospace & defense

# %%
itep_corp_indust_B['Industry'].value_counts().plot(kind='bar')

# %% [markdown]
# ## Creating one table containing all data for each company:
#
# ### Current tables:
# - `ips_appendix1_A`
# - `itep_tax_rates_B`
# - `itep_foreign_B`
# - `itep_corp_indust_B`
#
# ### All data:
# - Profit
# - Tax
# - Rate (US)
# - Industry
# - Story
#
# ### Some data:
# - Employee Change %
# - CEO compensation change %
# - Rate (Foreign)

# %%
master_table = itep_tax_rates_B.copy()

# %%
ips_appendix1_A.index.difference(master_table.index)
# Out:
# Index(['21st Century Fox', 'Commty Health Systems', 'ExxonMobil', 'IBM',
#        'JPMorgan Chase', 'PNC Financial Services', 'Public Service Enterprise',
#        'Reinsurance Grp of Amer', 'Travelers', 'Verizon', 'WEC',
#        'Wyndham Worldwide'],
#       dtype='object', name='Company Name')

# %%
ips_appendix1_A.rename({'21st Century Fox': 'Twenty-First Century Fox',
                       'Commty Health Systems': 'Community Health Systems',
                       'ExxonMobil': 'Exxon Mobil',
                        'JPMorgan Chase': 'J.P. Morgan Chase & Co.',
                        'PNC Financial Services': 'PNC Financial Services Group',
                        'Reinsurance Grp of Amer': 'Reinsurance Group of America',
                        'Travelers': 'Travelers Cos.',
                        'Verizon': 'Verizon Communications'}, inplace=True)

master_table.rename({'International Business Machines': 'IBM',
                     'Wisconsin Energy': 'WEC',
                     'Wyndham Worldwide Corporation':'Wyndham Worldwide'}, inplace=True)

# pd.concat([master_table, ips_appendix1_A['']], axis=1)
ips_appendix1_A['CEO compensation ($ 2016)	CEO', 'compensation % change (2008-2016)']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/ganeshravichandran/anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2392             try:
# -> 2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20405)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20359)()
#
# KeyError: ('CEO compensation ($ 2016)\tCEO', 'compensation % change (2008-2016)')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-c1359a283489> in <module>()
#      13
#      14 # pd.concat([master_table, ips_appendix1_A['']], axis=1)
# ---> 15 ips_appendix1_A['CEO compensation ($ 2016)      CEO', 'compensation % change (2008-2016)']
#
# /Users/ganeshravichandran/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2060             return self._getitem_multilevel(key)
#    2061         else:
# -> 2062             return self._getitem_column(key)
#    2063
#    2064     def _getitem_column(self, key):
#
# /Users/ganeshravichandran/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2067         # get column
#    2068         if self.columns.is_unique:
# -> 2069             return self._get_item_cache(key)
#    2070
#    2071         # duplicate columns & possible reduce dimensionality
#
# /Users/ganeshravichandran/anaconda/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1532         res = cache.get(item)
#    1533         if res is None:
# -> 1534             values = self._data.get(item)
#    1535             res = self._box_item_values(item, values)
#    1536             cache[item] = res
#
# /Users/ganeshravichandran/anaconda/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/ganeshravichandran/anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
# -> 2395                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2396
#    2397         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20405)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20359)()
#
# KeyError: ('CEO compensation ($ 2016)\tCEO', 'compensation % change (2008-2016)')
